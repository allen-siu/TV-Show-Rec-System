# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
anime_csv_path = 'csv_output/anime.csv'
ratings_csv_path = 'csv_output/rating.csv'

# %%
anime_data = pd.read_csv(anime_csv_path)
anime_data['genre'].fillna('', inplace=True)

ratings_data = pd.read_csv(ratings_csv_path)

# %%
user_anime_ratings = ratings_data.pivot_table(index='user_id', columns='anime_id', values='rating')
user_anime_ratings.replace(-1, np.nan, inplace=True)
user_anime_ratings
# Out:
# anime_id  1      5      6      7      8      15     16     17     18     \
# user_id
# 1           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5           NaN    NaN    8.0    NaN    NaN    6.0    NaN    6.0    6.0
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73512       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73513       9.0    8.0    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73514       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73515      10.0   10.0   10.0    NaN    NaN    NaN    NaN    NaN    NaN
# 73516       NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# anime_id  19     ...  34283  34324  34325  34349  34358  34367  34412  34475  \
# user_id          ...
# 1           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 5           NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...         ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 73512       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73513       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73514       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73515       9.0  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 73516       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# anime_id  34476  34519
# user_id
# 1           NaN    NaN
# 2           NaN    NaN
# 3           NaN    NaN
# 4           NaN    NaN
# 5           NaN    NaN
# ...         ...    ...
# 73512       NaN    NaN
# 73513       NaN    NaN
# 73514       NaN    NaN
# 73515       NaN    NaN
# 73516       NaN    NaN
#
# [73515 rows x 11200 columns]

# %%
# Normalize and scale ratings across users
normalized_ratings = user_anime_ratings.apply(
    lambda user: user - user.mean(),
    axis=1
)
# normalized_ratings = normalized_ratings.apply(
#     lambda user: (user) / (user.max() - user.min()),
#     axis=1
# )
normalized_ratings
# Out:
# anime_id     1         5         6      7      8        15     16       17     \
# user_id
# 1              NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 2              NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 3              NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 4              NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 5              NaN       NaN  3.644880    NaN    NaN  1.64488    NaN  1.64488
# ...            ...       ...       ...    ...    ...      ...    ...      ...
# 73512          NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 73513     1.484848  0.484848       NaN    NaN    NaN      NaN    NaN      NaN
# 73514          NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
# 73515     1.452514  1.452514  1.452514    NaN    NaN      NaN    NaN      NaN
# 73516          NaN       NaN       NaN    NaN    NaN      NaN    NaN      NaN
#
# anime_id    18        19     ...  34283  34324  34325  34349  34358  34367  \
# user_id                      ...
# 1             NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 2             NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 3             NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 4             NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 5         1.64488       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# ...           ...       ...  ...    ...    ...    ...    ...    ...    ...
# 73512         NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 73513         NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 73514         NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 73515         NaN  0.452514  ...    NaN    NaN    NaN    NaN    NaN    NaN
# 73516         NaN       NaN  ...    NaN    NaN    NaN    NaN    NaN    NaN
#
# anime_id  34412  34475  34476  34519
# user_id
# 1           NaN    NaN    NaN    NaN
# 2           NaN    NaN    NaN    NaN
# 3           NaN    NaN    NaN    NaN
# 4           NaN    NaN    NaN    NaN
# 5           NaN    NaN    NaN    NaN
# ...         ...    ...    ...    ...
# 73512       NaN    NaN    NaN    NaN
# 73513       NaN    NaN    NaN    NaN
# 73514       NaN    NaN    NaN    NaN
# 73515       NaN    NaN    NaN    NaN
# 73516       NaN    NaN    NaN    NaN
#
# [73515 rows x 11200 columns]

# %%
num_features = 3
# p_len, q_len = normalized_ratings.shape
# r = normalized_ratings

p_len, q_len = 70000, 5000
r = normalized_ratings.iloc[0:p_len, 0:q_len]

p = np.random.random(size=(p_len, num_features))
q = np.random.random(size=(q_len, num_features))

epochs = 20
alpha = 0.00001
lambda_reg = 0.1

for _ in range(epochs):
    r_hat = p @ q.T
    error = (r - r_hat)
    error.fillna(0, inplace=True)
    
    loss = error**2
    
    p_update = error.to_numpy() @ q
    q_update = error.to_numpy().T @ p

    # Update p and q
    p = p + alpha * (p_update - lambda_reg * p)
    q = q + alpha * (q_update - lambda_reg * q)

    print(loss.sum().sum())

r_pred = p @ q.T
r_pred = pd.DataFrame(r_pred, index=r.index, columns=r.columns)
r_pred = r_pred.round(2)
r_pred
# Out:
# 8799657.59446765
# 7521236.022190613
# 8822218.426970769
# 18400127.031925853
# 64782489.18010231
# 100053039.121139
# 21113742.964853168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 18
#      16 r_hat = p @ q.T
#      17 error = (r_hat - r)
# ---> 18 error.fillna(0, inplace=True)
#      20 loss = error**2
#      22 p_update = error.to_numpy() @ q
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\frame.py:5493, in DataFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    5482 @doc(NDFrame.fillna, **_shared_doc_kwargs)
#    5483 def fillna(
#    5484     self,
#    (...)
#    5491     downcast: dict | None = None,
#    5492 ) -> DataFrame | None:
# -> 5493     return super().fillna(
#    5494         value=value,
#    5495         method=method,
#    5496         axis=axis,
#    5497         inplace=inplace,
#    5498         limit=limit,
#    5499         downcast=downcast,
#    5500     )
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\generic.py:6983, in NDFrame.fillna(self, value, method, axis, inplace, limit, downcast)
#    6981         new_data = result
#    6982     else:
# -> 6983         new_data = self._mgr.fillna(
#    6984             value=value, limit=limit, inplace=inplace, downcast=downcast
#    6985         )
#    6986 elif isinstance(value, ABCDataFrame) and self.ndim == 2:
#    6987     new_data = self.where(self.notna(), value)._mgr
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:433, in BaseBlockManager.fillna(self, value, limit, inplace, downcast)
#     429 if limit is not None:
#     430     # Do this validation even if we go through one of the no-op paths
#     431     limit = libalgos.validate_limit(None, limit=limit)
# --> 433 return self.apply(
#     434     "fillna",
#     435     value=value,
#     436     limit=limit,
#     437     inplace=inplace,
#     438     downcast=downcast,
#     439     using_cow=using_copy_on_write(),
#     440 )
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:352, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     350         applied = b.apply(f, **kwargs)
#     351     else:
# --> 352         applied = getattr(b, f)(**kwargs)
#     353     result_blocks = extend_blocks(applied, result_blocks)
#     355 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1302, in Block.fillna(self, value, limit, inplace, downcast, using_cow)
#    1299     mask[mask.cumsum(self.ndim - 1) > limit] = False
#    1301 if inplace:
# -> 1302     nbs = self.putmask(mask.T, value, using_cow=using_cow)
#    1303 else:
#    1304     # without _downcast, we would break
#    1305     #  test_fillna_dtype_conversion_equiv_replace
#    1306     nbs = self.where(value, ~mask.T, _downcast=False)
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:1111, in Block.putmask(self, mask, new, using_cow)
#    1108     values = values.copy()
#    1109     self = self.make_block_same_class(values)
# -> 1111 putmask_without_repeat(values.T, mask, casted)
#    1112 if using_cow:
#    1113     return [self.copy(deep=False)]
#
# File c:\Users\allen\anaconda3\Lib\site-packages\pandas\core\array_algos\putmask.py:101, in putmask_without_repeat(values, mask, new)
#      99         raise ValueError("cannot assign mismatch length to masked array")
#     100 else:
# --> 101     np.putmask(values, mask, new)
#
# File <__array_function__ internals>:200, in putmask(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
r
# Out:
# anime_id  1     5        6     7     8         15    16       17        18    \
# user_id
# 1          NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 2          NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 3          NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 4          NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 5          NaN   NaN  3.64488   NaN   NaN  1.644880   NaN  1.64488  1.644880
# ...        ...   ...      ...   ...   ...       ...   ...      ...       ...
# 69997      NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN  0.688889
# 69998      NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 69999      NaN   NaN      NaN   NaN   NaN -0.016393   NaN      NaN       NaN
# 70000      NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
# 70001      NaN   NaN      NaN   NaN   NaN       NaN   NaN      NaN       NaN
#
# anime_id  19    ...  7416  7419  7420  7423  7427  7430  7435  7436  7445  \
# user_id         ...
# 1          NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2          NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3          NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4          NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5          NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...        ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 69997      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 69998      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 69999      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 70000      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 70001      NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# anime_id  7446
# user_id
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# ...        ...
# 69997      NaN
# 69998      NaN
# 69999      NaN
# 70000      NaN
# 70001      NaN
#
# [70000 rows x 5000 columns]

# %%
a = {
    1: [1, 2, 3],
    2: [4, 5, 6],
    3: [np.nan, np.nan, np.nan]
}
a = pd.DataFrame(a)
print(a)

b = a.apply(
    lambda user: user - user.mean(),
    axis=1
)
print(b)

c = b.apply(
    lambda user: (user - user.min()) / (user.max() - user.min()),
    axis=1
)
print(c)

d = {
    1: [1, 2, 3],
    2: [4, 5, 6],
    3: [7, 8, 9]
}
d = pd.DataFrame(d)
print(d)

print(a - d)
# Out:
#    1  2   3
# 0  1  4 NaN
# 1  2  5 NaN
# 2  3  6 NaN
#      1    2   3
# 0 -1.5  1.5 NaN
# 1 -1.5  1.5 NaN
# 2 -1.5  1.5 NaN
#      1    2   3
# 0  0.0  1.0 NaN
# 1  0.0  1.0 NaN
# 2  0.0  1.0 NaN
#    1  2  3
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9
#    1  2   3
# 0  0  0 NaN
# 1  0  0 NaN
# 2  0  0 NaN

# %%
a = np.array([[1, 2, 3],
              [3, 4, 5]])
b = np.array([[3, 4, 5],
              [5, 6, 7]])

a @ b.T
# Out:
# array([[26, 38],
#        [50, 74]])
